# %% [markdown]
# Selecting Subsets of Data
#
# In this chapter, we will cover the following topics:
#
#     Selecting Series data
#     Selecting DataFrame rows
#     Selecting DataFrame rows and columns simultaneously
#     Selecting data with both integers and labels
#     Speeding up scalar selection
#     Slicing rows lazily
#     Slicing lexicographically

# %% [markdown]
#     Both .loc and .iloc work with Series and DataFrames.
#     This recipe shows how to select Series data
#     by integer location with .iloc and
#     by label with .loc. These indexers not only take scalar values, but also lists and slices.

# %%
import pandas as pd 
college = pd.read_csv('data/college.csv', index_col='INSTNM')
city = college['CITY']

# %%
print(city.head())
print(city.shape)
# Out:
# INSTNM
# Alabama A & M University                   Normal
# University of Alabama at Birmingham    Birmingham
# Amridge University                     Montgomery
# University of Alabama in Huntsville    Huntsville
# Alabama State University               Montgomery
# Name: CITY, dtype: object
# (7535,)

# %%
print("city[3]",city[3])
print("city.iloc[3]",city.iloc[3])
print("\ncity.iloc[[10,20,30]]\n",city.iloc[[10,20,30]])
# Out:
# city[3] Huntsville
# city.iloc[3] Huntsville
#
# city.iloc[[10,20,30]]
#  INSTNM
# Birmingham Southern College                            Birmingham
# George C Wallace State Community College-Hanceville    Hanceville
# Judson College                                             Marion
# Name: CITY, dtype: object

# %% [markdown]
# #### .loc indexer
# .loc indexer, which selects only with index labels. Passing a single string returns a scalar value

# %%
city.loc['Heritage Christian University']
# Out:
# 'Florence'

# %%
print ("city.loc[1] gives error")
# Out:
# city.loc[1] gives error

# %%
city.iloc[[3]]
# Out:
# INSTNM
# University of Alabama in Huntsville    Huntsville
# Name: CITY, dtype: object

# %%
city.iloc[3]
# Out:
# 'Huntsville'

# %% [markdown]
# **Selecting DataFrame rows**
#
# The most explicit and preferred way to select DataFrame rows is with the _.iloc_ and _.loc_
# indexers. They are capable of selecting rows or columns independently and
# simultaneously.

# %%
college.iloc[3].T
# Out:
# CITY                  Huntsville
# STABBR                        AL
# HBCU                           0
# MENONLY                        0
# WOMENONLY                      0
# RELAFFIL                       0
# SATVRMID                     595
# SATMTMID                     590
# DISTANCEONLY                   0
# UGDS                        5451
# UGDS_WHITE                0.6988
# UGDS_BLACK                0.1255
# UGDS_HISP                 0.0382
# UGDS_ASIAN                0.0376
# UGDS_AIAN                 0.0143
# UGDS_NHPI                 0.0002
# UGDS_2MOR                 0.0172
# UGDS_NRA                  0.0332
# UGDS_UNKN                  0.035
# PPTUG_EF                  0.2146
# CURROPER                       1
# PCTPELL                   0.3072
# PCTFLOAN                  0.4596
# UG25ABV                    0.264
# MD_EARN_WNE_P10            45500
# GRAD_DEBT_MDN_SUPP         24097
# Name: University of Alabama in Huntsville, dtype: object

# %%
# Using iloc to get the same result
college.loc['University of Alabama in Huntsville']
# Out:
# CITY                  Huntsville
# STABBR                        AL
# HBCU                           0
# MENONLY                        0
# WOMENONLY                      0
# RELAFFIL                       0
# SATVRMID                     595
# SATMTMID                     590
# DISTANCEONLY                   0
# UGDS                        5451
# UGDS_WHITE                0.6988
# UGDS_BLACK                0.1255
# UGDS_HISP                 0.0382
# UGDS_ASIAN                0.0376
# UGDS_AIAN                 0.0143
# UGDS_NHPI                 0.0002
# UGDS_2MOR                 0.0172
# UGDS_NRA                  0.0332
# UGDS_UNKN                  0.035
# PPTUG_EF                  0.2146
# CURROPER                       1
# PCTPELL                   0.3072
# PCTFLOAN                  0.4596
# UG25ABV                    0.264
# MD_EARN_WNE_P10            45500
# GRAD_DEBT_MDN_SUPP         24097
# Name: University of Alabama in Huntsville, dtype: object

# %%
# To fetch rows based on row numbers 
college.iloc[[10,20,22]]
# Out:
#                                                           CITY STABBR  HBCU  \
# INSTNM
# Birmingham Southern College                         Birmingham     AL   0.0
# George C Wallace State Community College-Hancev...  Hanceville     AL   0.0
# Herzing University-Birmingham                       Birmingham     AL   0.0
#
#                                                     MENONLY  WOMENONLY  \
# INSTNM
# Birmingham Southern College                             0.0        0.0
# George C Wallace State Community College-Hancev...      0.0        0.0
# Herzing University-Birmingham                           0.0        0.0
#
#                                                     RELAFFIL  SATVRMID  \
# INSTNM
# Birmingham Southern College                                1     560.0
# George C Wallace State Community College-Hancev...         0       NaN
# Herzing University-Birmingham                              0       NaN
#
#                                                     SATMTMID  DISTANCEONLY  \
# INSTNM
# Birmingham Southern College                            560.0           0.0
# George C Wallace State Community College-Hancev...       NaN           0.0
# Herzing University-Birmingham                            NaN           0.0
#
#                                                       UGDS  \
# INSTNM
# Birmingham Southern College                         1180.0
# George C Wallace State Community College-Hancev...  4920.0
# Herzing University-Birmingham                        302.0
#
#                                                            ...          \
# INSTNM                                                     ...
# Birmingham Southern College                                ...
# George C Wallace State Community College-Hancev...         ...
# Herzing University-Birmingham                              ...
#
#                                                     UGDS_2MOR  UGDS_NRA  \
# INSTNM
# Birmingham Southern College                            0.0051    0.0000
# George C Wallace State Community College-Hancev...     0.0000    0.0059
# Herzing University-Birmingham                          0.0563    0.0000
#
#                                                     UGDS_UNKN  PPTUG_EF  \
# INSTNM
# Birmingham Southern College                            0.0051    0.0017
# George C Wallace State Community College-Hancev...     0.0183    0.4203
# Herzing University-Birmingham                          0.0397    0.5497
#
#                                                     CURROPER  PCTPELL  \
# INSTNM
# Birmingham Southern College                                1   0.1920
# George C Wallace State Community College-Hancev...         1   0.5026
# Herzing University-Birmingham                              1   0.6541
#
#                                                     PCTFLOAN  UG25ABV  \
# INSTNM
# Birmingham Southern College                           0.4809   0.0152
# George C Wallace State Community College-Hancev...    0.4192   0.3229
# Herzing University-Birmingham                         0.7736   0.7813
#
#                                                     MD_EARN_WNE_P10  \
# INSTNM
# Birmingham Southern College                                   44200
# George C Wallace State Community College-Hancev...            28800
# Herzing University-Birmingham                                 42300
#
#                                                     GRAD_DEBT_MDN_SUPP
# INSTNM
# Birmingham Southern College                                      27000
# George C Wallace State Community College-Hancev...               11186
# Herzing University-Birmingham                                  23216.5
#
# [3 rows x 26 columns]

# %%
# Fetch the rows based on index names
labels = ['University of Alaska Anchorage',
'International Academy of Hair Design',
'University of Alabama in Huntsville']
college.loc[labels]
# Out:
#                                             CITY STABBR  HBCU  MENONLY  \
# INSTNM
# University of Alaska Anchorage         Anchorage     AK   0.0      0.0
# International Academy of Hair Design       Tempe     AZ   0.0      0.0
# University of Alabama in Huntsville   Huntsville     AL   0.0      0.0
#
#                                       WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# University of Alaska Anchorage              0.0         0       NaN       NaN
# International Academy of Hair Design        0.0         0       NaN       NaN
# University of Alabama in Huntsville         0.0         0     595.0     590.0
#
#                                       DISTANCEONLY     UGDS  \
# INSTNM
# University of Alaska Anchorage                 0.0  12865.0
# International Academy of Hair Design           0.0    188.0
# University of Alabama in Huntsville            0.0   5451.0
#
#                                              ...          UGDS_2MOR  UGDS_NRA  \
# INSTNM                                       ...
# University of Alaska Anchorage               ...             0.0980    0.0181
# International Academy of Hair Design         ...             0.0160    0.0000
# University of Alabama in Huntsville          ...             0.0172    0.0332
#
#                                       UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  \
# INSTNM
# University of Alaska Anchorage           0.0457    0.4539         1   0.2385
# International Academy of Hair Design     0.0638    0.0000         0   0.7185
# University of Alabama in Huntsville      0.0350    0.2146         1   0.3072
#
#                                       PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# INSTNM
# University of Alaska Anchorage          0.2647   0.4386            42500
# International Academy of Hair Design    0.7346   0.3905            22200
# University of Alabama in Huntsville     0.4596   0.2640            45500
#
#                                       GRAD_DEBT_MDN_SUPP
# INSTNM
# University of Alaska Anchorage                   19449.5
# International Academy of Hair Design               10556
# University of Alabama in Huntsville                24097
#
# [3 rows x 26 columns]

# %%
# Use slice notation with .iloc to select an entire segment of the data
college.iloc[93:98]
# Out:
#                                                      CITY STABBR  HBCU  \
# INSTNM
# Avalon School of Cosmetology-Mesa                    Mesa     AZ   0.0
# Eastern Arizona College                          Thatcher     AZ   0.0
# Embry-Riddle Aeronautical University-Prescott    Prescott     AZ   0.0
# Frank Lloyd Wright School of Architecture      Scottsdale     AZ   0.0
# Glendale Community College                       Glendale     AZ   0.0
#
#                                                MENONLY  WOMENONLY  RELAFFIL  \
# INSTNM
# Avalon School of Cosmetology-Mesa                  0.0        0.0         0
# Eastern Arizona College                            0.0        0.0         0
# Embry-Riddle Aeronautical University-Prescott      0.0        0.0         0
# Frank Lloyd Wright School of Architecture          0.0        0.0         0
# Glendale Community College                         0.0        0.0         0
#
#                                                SATVRMID  SATMTMID  \
# INSTNM
# Avalon School of Cosmetology-Mesa                   NaN       NaN
# Eastern Arizona College                             NaN       NaN
# Embry-Riddle Aeronautical University-Prescott       NaN       NaN
# Frank Lloyd Wright School of Architecture           NaN       NaN
# Glendale Community College                          NaN       NaN
#
#                                                DISTANCEONLY     UGDS  \
# INSTNM
# Avalon School of Cosmetology-Mesa                       0.0    360.0
# Eastern Arizona College                                 0.0   4634.0
# Embry-Riddle Aeronautical University-Prescott           0.0   1971.0
# Frank Lloyd Wright School of Architecture               0.0      NaN
# Glendale Community College                              0.0  16156.0
#
#                                                       ...          UGDS_2MOR  \
# INSTNM                                                ...
# Avalon School of Cosmetology-Mesa                     ...             0.0250
# Eastern Arizona College                               ...             0.0108
# Embry-Riddle Aeronautical University-Prescott         ...             0.0939
# Frank Lloyd Wright School of Architecture             ...                NaN
# Glendale Community College                            ...             0.0221
#
#                                                UGDS_NRA  UGDS_UNKN  PPTUG_EF  \
# INSTNM
# Avalon School of Cosmetology-Mesa                0.0000     0.0222    0.3667
# Eastern Arizona College                          0.0093     0.0358    0.6196
# Embry-Riddle Aeronautical University-Prescott    0.0989     0.0949    0.0518
# Frank Lloyd Wright School of Architecture           NaN        NaN       NaN
# Glendale Community College                       0.0106     0.0480    0.6157
#
#                                                CURROPER  PCTPELL  PCTFLOAN  \
# INSTNM
# Avalon School of Cosmetology-Mesa                     1   0.6218    0.6495
# Eastern Arizona College                               1   0.1859    0.0000
# Embry-Riddle Aeronautical University-Prescott         1   0.2501    0.5189
# Frank Lloyd Wright School of Architecture             1      NaN       NaN
# Glendale Community College                            1   0.3824    0.1784
#
#                                                UG25ABV  MD_EARN_WNE_P10  \
# INSTNM
# Avalon School of Cosmetology-Mesa               0.2930            19600
# Eastern Arizona College                         0.5279            28700
# Embry-Riddle Aeronautical University-Prescott   0.1208            61500
# Frank Lloyd Wright School of Architecture       0.0000              NaN
# Glendale Community College                      0.3324            33600
#
#                                                GRAD_DEBT_MDN_SUPP
# INSTNM
# Avalon School of Cosmetology-Mesa                           11458
# Eastern Arizona College                         PrivacySuppressed
# Embry-Riddle Aeronautical University-Prescott               24411
# Frank Lloyd Wright School of Architecture       PrivacySuppressed
# Glendale Community College                                   7000
#
# [5 rows x 26 columns]

# %%
>>> start = 'International Academy of Hair Design'
>>> stop = 'Mesa Community College'
>>> college.loc[start:stop]
# Out:
#                                          CITY STABBR  HBCU  MENONLY  \
# INSTNM
# International Academy of Hair Design    Tempe     AZ   0.0      0.0
# GateWay Community College             Phoenix     AZ   0.0      0.0
# Mesa Community College                   Mesa     AZ   0.0      0.0
#
#                                       WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# International Academy of Hair Design        0.0         0       NaN       NaN
# GateWay Community College                   0.0         0       NaN       NaN
# Mesa Community College                      0.0         0       NaN       NaN
#
#                                       DISTANCEONLY     UGDS  \
# INSTNM
# International Academy of Hair Design           0.0    188.0
# GateWay Community College                      0.0   5211.0
# Mesa Community College                         0.0  19055.0
#
#                                              ...          UGDS_2MOR  UGDS_NRA  \
# INSTNM                                       ...
# International Academy of Hair Design         ...             0.0160    0.0000
# GateWay Community College                    ...             0.0127    0.0161
# Mesa Community College                       ...             0.0205    0.0257
#
#                                       UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  \
# INSTNM
# International Academy of Hair Design     0.0638    0.0000         0   0.7185
# GateWay Community College                0.0702    0.7465         1   0.3270
# Mesa Community College                   0.0682    0.6457         1   0.3423
#
#                                       PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# INSTNM
# International Academy of Hair Design    0.7346   0.3905            22200
# GateWay Community College               0.2189   0.5832            29800
# Mesa Community College                  0.2207   0.4010            35200
#
#                                       GRAD_DEBT_MDN_SUPP
# INSTNM
# International Academy of Hair Design               10556
# GateWay Community College                           7283
# Mesa Community College                              8000
#
# [3 rows x 26 columns]

# %%
college.iloc[2:4]
# Out:
#                                            CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Amridge University                   Montgomery     AL   0.0      0.0
# University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
#
#                                      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# Amridge University                         0.0         1       NaN       NaN
# University of Alabama in Huntsville        0.0         0     595.0     590.0
#
#                                      DISTANCEONLY    UGDS         ...          \
# INSTNM                                                            ...
# Amridge University                            1.0   291.0         ...
# University of Alabama in Huntsville           0.0  5451.0         ...
#
#                                      UGDS_2MOR  UGDS_NRA  UGDS_UNKN  PPTUG_EF  \
# INSTNM
# Amridge University                      0.0000    0.0000     0.2715    0.4536
# University of Alabama in Huntsville     0.0172    0.0332     0.0350    0.2146
#
#                                      CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# INSTNM
# Amridge University                          1   0.6801    0.7795    0.854
# University of Alabama in Huntsville         1   0.3072    0.4596    0.264
#
#                                      MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# INSTNM
# Amridge University                             40100               23370
# University of Alabama in Huntsville            45500               24097
#
# [2 rows x 26 columns]
